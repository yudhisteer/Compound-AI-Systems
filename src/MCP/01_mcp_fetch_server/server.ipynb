# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace
from agents.mcp import MCPServerStdio
import os

# %%
fetch_params = {"command": "uvx", "args": ["mcp-server-fetch"]}

async with MCPServerStdio(params=fetch_params) as server:
    fetch_tools = await server.list_tools()

for tool in fetch_tools:
    print(f"{tool.name}: {tool.description.replace('\n', ' ')}")
# Out:
# Error initializing MCP server:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File c:\Users\v-ychintaram\OneDrive - Microsoft\Desktop\__Project__\Compound-AI-Systems\.venv\Lib\site-packages\mcp\client\stdio\win32.py:72, in create_windows_process(command, args, env, errlog, cwd)
#      70 try:
#      71     # Try with Windows-specific flags to hide console window
# ---> 72     process = await anyio.open_process(
#      73         [command, *args],
#      74         env=env,
#      75         # Ensure we don't create console windows for each process
#      76         creationflags=subprocess.CREATE_NO_WINDOW  # type: ignore
#      77         if hasattr(subprocess, "CREATE_NO_WINDOW")
#      78         else 0,
#      79         stderr=errlog,
#      80         cwd=cwd,
#      81     )
#      82     return process
#
# File c:\Users\v-ychintaram\OneDrive - Microsoft\Desktop\__Project__\Compound-AI-Systems\.venv\Lib\site-packages\anyio\_core\_subprocesses.py:190, in open_process(command, stdin, stdout, stderr, cwd, env, startupinfo, creationflags, start_new_session, pass_fds, user, group, extra_groups, umask)
#     188     kwargs["umask"] = umask
# --> 190 return await get_async_backend().open_process(
#     191     command,
#     192     stdin=stdin,
#     193     stdout=stdout,
#     194     stderr=stderr,
#     195     cwd=cwd,
#     196     env=env,
#     197     startupinfo=startupinfo,
#     198     creationflags=creationflags,
#     199     start_new_session=start_new_session,
#     200     pass_fds=pass_fds,
#     201     **kwargs,
#     202 )
#
# File c:\Users\v-ychintaram\OneDrive - Microsoft\Desktop\__Project__\Compound-AI-Systems\.venv\Lib\site-packages\anyio\_backends\_asyncio.py:2561, in AsyncIOBackend.open_process(cls, command, stdin, stdout, stderr, **kwargs)
#    2560 else:
# -> 2561     process = await asyncio.create_subprocess_exec(
#    2562         *command,
#    2563         stdin=stdin,
#    2564         stdout=stdout,
#    2565         stderr=stderr,
#    2566         **kwargs,
#    2567     )
#    2569 stdin_stream = StreamWriterWrapper(process.stdin) if process.stdin else None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\subprocess.py:224, in create_subprocess_exec(program, stdin, stdout, stderr, limit, *args, **kwds)
#     222 protocol_factory = lambda: SubprocessStreamProtocol(limit=limit,
#     223                                                     loop=loop)
# --> 224 transport, protocol = await loop.subprocess_exec(
#     225     protocol_factory,
#     226     program, *args,
#     227     stdin=stdin, stdout=stdout,
#     228     stderr=stderr, **kwds)
#     229 return Process(transport, protocol, loop)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py:1756, in BaseEventLoop.subprocess_exec(self, protocol_factory, program, stdin, stdout, stderr, universal_newlines, shell, bufsize, encoding, errors, text, *args, **kwargs)
#    1755     self._log_subprocess(debug_log, stdin, stdout, stderr)
# -> 1756 transport = await self._make_subprocess_transport(
#    1757     protocol, popen_args, False, stdin, stdout, stderr,
#    1758     bufsize, **kwargs)
#    1759 if self._debug and debug_log is not None:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py:528, in BaseEventLoop._make_subprocess_transport(self, protocol, args, shell, stdin, stdout, stderr, bufsize, extra, **kwargs)
#     527 """Create subprocess transport."""
# --> 528 raise NotImplementedError
#
# NotImplementedError:
#
# During handling of the above exception, another exception occurred:
#
# NotImplementedError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 fetch_params = {"command": "uv", "args": ["mcp-server-fetch"]}
# ----> 3 async with MCPServerStdio(params=fetch_params) as server:
#       4     fetch_tools = await server.list_tools()
#       6 for tool in fetch_tools:
#
# File c:\Users\v-ychintaram\OneDrive - Microsoft\Desktop\__Project__\Compound-AI-Systems\.venv\Lib\site-packages\agents\mcp\server.py:89, in _MCPServerWithClientSession.__aenter__(self)
#      88 async def __aenter__(self):
# ---> 89     await self.connect()
#      90     return self
#
# File c:\Users\v-ychintaram\OneDrive - Microsoft\Desktop\__Project__\Compound-AI-Systems\.venv\Lib\site-packages\agents\mcp\server.py:102, in _MCPServerWithClientSession.connect(self)
#     100 """Connect to the server."""
#     101 try:
# --> 102     transport = await self.exit_stack.enter_async_context(self.create_streams())
#     103     read, write = transport
#     104     session = await self.exit_stack.enter_async_context(ClientSession(read, write))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:659, in AsyncExitStack.enter_async_context(self, cm)
#     655 except AttributeError:
#     656     raise TypeError(f"'{cls.__module__}.{cls.__qualname__}' object does "
#     657                     f"not support the asynchronous context manager protocol"
#     658                    ) from None
# --> 659 result = await _enter(cm)
#     660 self._push_async_cm_exit(cm, _exit)
#     661 return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:210, in _AsyncGeneratorContextManager.__aenter__(self)
#     208 del self.args, self.kwds, self.func
#     209 try:
# --> 210     return await anext(self.gen)
#     211 except StopAsyncIteration:
#     212     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\v-ychintaram\OneDrive - Microsoft\Desktop\__Project__\Compound-AI-Systems\.venv\Lib\site-packages\mcp\client\stdio\__init__.py:113, in stdio_client(server, errlog)
#     110 command = _get_executable_command(server.command)
#     112 # Open process with stderr piped for capture
# --> 113 process = await _create_platform_compatible_process(
#     114     command=command,
#     115     args=server.args,
#     116     env=(
#     117         {**get_default_environment(), **server.env}
#     118         if server.env is not None
#     119         else get_default_environment()
#     120     ),
#     121     errlog=errlog,
#     122     cwd=server.cwd,
#     123 )
#     125 async def stdout_reader():
#     126     assert process.stdout, "Opened process is missing stdout"
#
# File c:\Users\v-ychintaram\OneDrive - Microsoft\Desktop\__Project__\Compound-AI-Systems\.venv\Lib\site-packages\mcp\client\stdio\__init__.py:210, in _create_platform_compatible_process(command, args, env, errlog, cwd)
#     205 """
#     206 Creates a subprocess in a platform-compatible way.
#     207 Returns a process handle.
#     208 """
#     209 if sys.platform == "win32":
# --> 210     process = await create_windows_process(command, args, env, errlog, cwd)
#     211 else:
#     212     process = await anyio.open_process(
#     213         [command, *args], env=env, stderr=errlog, cwd=cwd
#     214     )
#
# File c:\Users\v-ychintaram\OneDrive - Microsoft\Desktop\__Project__\Compound-AI-Systems\.venv\Lib\site-packages\mcp\client\stdio\win32.py:85, in create_windows_process(command, args, env, errlog, cwd)
#      82     return process
#      83 except Exception:
#      84     # Don't raise, let's try to create the process without creation flags
# ---> 85     process = await anyio.open_process(
#      86         [command, *args], env=env, stderr=errlog, cwd=cwd
#      87     )
#      88     return process
#
# File c:\Users\v-ychintaram\OneDrive - Microsoft\Desktop\__Project__\Compound-AI-Systems\.venv\Lib\site-packages\anyio\_core\_subprocesses.py:190, in open_process(command, stdin, stdout, stderr, cwd, env, startupinfo, creationflags, start_new_session, pass_fds, user, group, extra_groups, umask)
#     187 if umask >= 0:
#     188     kwargs["umask"] = umask
# --> 190 return await get_async_backend().open_process(
#     191     command,
#     192     stdin=stdin,
#     193     stdout=stdout,
#     194     stderr=stderr,
#     195     cwd=cwd,
#     196     env=env,
#     197     startupinfo=startupinfo,
#     198     creationflags=creationflags,
#     199     start_new_session=start_new_session,
#     200     pass_fds=pass_fds,
#     201     **kwargs,
#     202 )
#
# File c:\Users\v-ychintaram\OneDrive - Microsoft\Desktop\__Project__\Compound-AI-Systems\.venv\Lib\site-packages\anyio\_backends\_asyncio.py:2561, in AsyncIOBackend.open_process(cls, command, stdin, stdout, stderr, **kwargs)
#    2553     process = await asyncio.create_subprocess_shell(
#    2554         command,
#    2555         stdin=stdin,
#    (...)   2558         **kwargs,
#    2559     )
#    2560 else:
# -> 2561     process = await asyncio.create_subprocess_exec(
#    2562         *command,
#    2563         stdin=stdin,
#    2564         stdout=stdout,
#    2565         stderr=stderr,
#    2566         **kwargs,
#    2567     )
#    2569 stdin_stream = StreamWriterWrapper(process.stdin) if process.stdin else None
#    2570 stdout_stream = StreamReaderWrapper(process.stdout) if process.stdout else None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\subprocess.py:224, in create_subprocess_exec(program, stdin, stdout, stderr, limit, *args, **kwds)
#     221 loop = events.get_running_loop()
#     222 protocol_factory = lambda: SubprocessStreamProtocol(limit=limit,
#     223                                                     loop=loop)
# --> 224 transport, protocol = await loop.subprocess_exec(
#     225     protocol_factory,
#     226     program, *args,
#     227     stdin=stdin, stdout=stdout,
#     228     stderr=stderr, **kwds)
#     229 return Process(transport, protocol, loop)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py:1756, in BaseEventLoop.subprocess_exec(self, protocol_factory, program, stdin, stdout, stderr, universal_newlines, shell, bufsize, encoding, errors, text, *args, **kwargs)
#    1754     debug_log = f'execute program {program!r}'
#    1755     self._log_subprocess(debug_log, stdin, stdout, stderr)
# -> 1756 transport = await self._make_subprocess_transport(
#    1757     protocol, popen_args, False, stdin, stdout, stderr,
#    1758     bufsize, **kwargs)
#    1759 if self._debug and debug_log is not None:
#    1760     logger.info('%s: %r', debug_log, transport)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py:528, in BaseEventLoop._make_subprocess_transport(self, protocol, args, shell, stdin, stdout, stderr, bufsize, extra, **kwargs)
#     524 async def _make_subprocess_transport(self, protocol, args, shell,
#     525                                      stdin, stdout, stderr, bufsize,
#     526                                      extra=None, **kwargs):
#     527     """Create subprocess transport."""
# --> 528     raise NotImplementedError
#
# NotImplementedError:

# %%
puppeteer_params = {"command": "npx", "args": ["-y", "@modelcontextprotocol/server-puppeteer"]}

async with MCPServerStdio(params=puppeteer_params) as server:
    puppeteer_tools = await server.list_tools()

for tool in puppeteer_tools:
    print(f"{tool.name}: {tool.description.replace('\n', ' ')}")
# Out:
# Error initializing MCP server:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File c:\Users\v-ychintaram\OneDrive - Microsoft\Desktop\__Project__\Compound-AI-Systems\.venv\Lib\site-packages\mcp\client\stdio\win32.py:72, in create_windows_process(command, args, env, errlog, cwd)
#      70 try:
#      71     # Try with Windows-specific flags to hide console window
# ---> 72     process = await anyio.open_process(
#      73         [command, *args],
#      74         env=env,
#      75         # Ensure we don't create console windows for each process
#      76         creationflags=subprocess.CREATE_NO_WINDOW  # type: ignore
#      77         if hasattr(subprocess, "CREATE_NO_WINDOW")
#      78         else 0,
#      79         stderr=errlog,
#      80         cwd=cwd,
#      81     )
#      82     return process
#
# File c:\Users\v-ychintaram\OneDrive - Microsoft\Desktop\__Project__\Compound-AI-Systems\.venv\Lib\site-packages\anyio\_core\_subprocesses.py:190, in open_process(command, stdin, stdout, stderr, cwd, env, startupinfo, creationflags, start_new_session, pass_fds, user, group, extra_groups, umask)
#     188     kwargs["umask"] = umask
# --> 190 return await get_async_backend().open_process(
#     191     command,
#     192     stdin=stdin,
#     193     stdout=stdout,
#     194     stderr=stderr,
#     195     cwd=cwd,
#     196     env=env,
#     197     startupinfo=startupinfo,
#     198     creationflags=creationflags,
#     199     start_new_session=start_new_session,
#     200     pass_fds=pass_fds,
#     201     **kwargs,
#     202 )
#
# File c:\Users\v-ychintaram\OneDrive - Microsoft\Desktop\__Project__\Compound-AI-Systems\.venv\Lib\site-packages\anyio\_backends\_asyncio.py:2561, in AsyncIOBackend.open_process(cls, command, stdin, stdout, stderr, **kwargs)
#    2560 else:
# -> 2561     process = await asyncio.create_subprocess_exec(
#    2562         *command,
#    2563         stdin=stdin,
#    2564         stdout=stdout,
#    2565         stderr=stderr,
#    2566         **kwargs,
#    2567     )
#    2569 stdin_stream = StreamWriterWrapper(process.stdin) if process.stdin else None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\subprocess.py:224, in create_subprocess_exec(program, stdin, stdout, stderr, limit, *args, **kwds)
#     222 protocol_factory = lambda: SubprocessStreamProtocol(limit=limit,
#     223                                                     loop=loop)
# --> 224 transport, protocol = await loop.subprocess_exec(
#     225     protocol_factory,
#     226     program, *args,
#     227     stdin=stdin, stdout=stdout,
#     228     stderr=stderr, **kwds)
#     229 return Process(transport, protocol, loop)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py:1756, in BaseEventLoop.subprocess_exec(self, protocol_factory, program, stdin, stdout, stderr, universal_newlines, shell, bufsize, encoding, errors, text, *args, **kwargs)
#    1755     self._log_subprocess(debug_log, stdin, stdout, stderr)
# -> 1756 transport = await self._make_subprocess_transport(
#    1757     protocol, popen_args, False, stdin, stdout, stderr,
#    1758     bufsize, **kwargs)
#    1759 if self._debug and debug_log is not None:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py:528, in BaseEventLoop._make_subprocess_transport(self, protocol, args, shell, stdin, stdout, stderr, bufsize, extra, **kwargs)
#     527 """Create subprocess transport."""
# --> 528 raise NotImplementedError
#
# NotImplementedError:
#
# During handling of the above exception, another exception occurred:
#
# NotImplementedError                       Traceback (most recent call last)
# Cell In[4], line 3
#       1 puppeteer_params = {"command": "npx", "args": ["-y", "@modelcontextprotocol/server-puppeteer"]}
# ----> 3 async with MCPServerStdio(params=puppeteer_params) as server:
#       4     puppeteer_tools = await server.list_tools()
#       6 for tool in puppeteer_tools:
#
# File c:\Users\v-ychintaram\OneDrive - Microsoft\Desktop\__Project__\Compound-AI-Systems\.venv\Lib\site-packages\agents\mcp\server.py:89, in _MCPServerWithClientSession.__aenter__(self)
#      88 async def __aenter__(self):
# ---> 89     await self.connect()
#      90     return self
#
# File c:\Users\v-ychintaram\OneDrive - Microsoft\Desktop\__Project__\Compound-AI-Systems\.venv\Lib\site-packages\agents\mcp\server.py:102, in _MCPServerWithClientSession.connect(self)
#     100 """Connect to the server."""
#     101 try:
# --> 102     transport = await self.exit_stack.enter_async_context(self.create_streams())
#     103     read, write = transport
#     104     session = await self.exit_stack.enter_async_context(ClientSession(read, write))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:659, in AsyncExitStack.enter_async_context(self, cm)
#     655 except AttributeError:
#     656     raise TypeError(f"'{cls.__module__}.{cls.__qualname__}' object does "
#     657                     f"not support the asynchronous context manager protocol"
#     658                    ) from None
# --> 659 result = await _enter(cm)
#     660 self._push_async_cm_exit(cm, _exit)
#     661 return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:210, in _AsyncGeneratorContextManager.__aenter__(self)
#     208 del self.args, self.kwds, self.func
#     209 try:
# --> 210     return await anext(self.gen)
#     211 except StopAsyncIteration:
#     212     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\v-ychintaram\OneDrive - Microsoft\Desktop\__Project__\Compound-AI-Systems\.venv\Lib\site-packages\mcp\client\stdio\__init__.py:113, in stdio_client(server, errlog)
#     110 command = _get_executable_command(server.command)
#     112 # Open process with stderr piped for capture
# --> 113 process = await _create_platform_compatible_process(
#     114     command=command,
#     115     args=server.args,
#     116     env=(
#     117         {**get_default_environment(), **server.env}
#     118         if server.env is not None
#     119         else get_default_environment()
#     120     ),
#     121     errlog=errlog,
#     122     cwd=server.cwd,
#     123 )
#     125 async def stdout_reader():
#     126     assert process.stdout, "Opened process is missing stdout"
#
# File c:\Users\v-ychintaram\OneDrive - Microsoft\Desktop\__Project__\Compound-AI-Systems\.venv\Lib\site-packages\mcp\client\stdio\__init__.py:210, in _create_platform_compatible_process(command, args, env, errlog, cwd)
#     205 """
#     206 Creates a subprocess in a platform-compatible way.
#     207 Returns a process handle.
#     208 """
#     209 if sys.platform == "win32":
# --> 210     process = await create_windows_process(command, args, env, errlog, cwd)
#     211 else:
#     212     process = await anyio.open_process(
#     213         [command, *args], env=env, stderr=errlog, cwd=cwd
#     214     )
#
# File c:\Users\v-ychintaram\OneDrive - Microsoft\Desktop\__Project__\Compound-AI-Systems\.venv\Lib\site-packages\mcp\client\stdio\win32.py:85, in create_windows_process(command, args, env, errlog, cwd)
#      82     return process
#      83 except Exception:
#      84     # Don't raise, let's try to create the process without creation flags
# ---> 85     process = await anyio.open_process(
#      86         [command, *args], env=env, stderr=errlog, cwd=cwd
#      87     )
#      88     return process
#
# File c:\Users\v-ychintaram\OneDrive - Microsoft\Desktop\__Project__\Compound-AI-Systems\.venv\Lib\site-packages\anyio\_core\_subprocesses.py:190, in open_process(command, stdin, stdout, stderr, cwd, env, startupinfo, creationflags, start_new_session, pass_fds, user, group, extra_groups, umask)
#     187 if umask >= 0:
#     188     kwargs["umask"] = umask
# --> 190 return await get_async_backend().open_process(
#     191     command,
#     192     stdin=stdin,
#     193     stdout=stdout,
#     194     stderr=stderr,
#     195     cwd=cwd,
#     196     env=env,
#     197     startupinfo=startupinfo,
#     198     creationflags=creationflags,
#     199     start_new_session=start_new_session,
#     200     pass_fds=pass_fds,
#     201     **kwargs,
#     202 )
#
# File c:\Users\v-ychintaram\OneDrive - Microsoft\Desktop\__Project__\Compound-AI-Systems\.venv\Lib\site-packages\anyio\_backends\_asyncio.py:2561, in AsyncIOBackend.open_process(cls, command, stdin, stdout, stderr, **kwargs)
#    2553     process = await asyncio.create_subprocess_shell(
#    2554         command,
#    2555         stdin=stdin,
#    (...)   2558         **kwargs,
#    2559     )
#    2560 else:
# -> 2561     process = await asyncio.create_subprocess_exec(
#    2562         *command,
#    2563         stdin=stdin,
#    2564         stdout=stdout,
#    2565         stderr=stderr,
#    2566         **kwargs,
#    2567     )
#    2569 stdin_stream = StreamWriterWrapper(process.stdin) if process.stdin else None
#    2570 stdout_stream = StreamReaderWrapper(process.stdout) if process.stdout else None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\subprocess.py:224, in create_subprocess_exec(program, stdin, stdout, stderr, limit, *args, **kwds)
#     221 loop = events.get_running_loop()
#     222 protocol_factory = lambda: SubprocessStreamProtocol(limit=limit,
#     223                                                     loop=loop)
# --> 224 transport, protocol = await loop.subprocess_exec(
#     225     protocol_factory,
#     226     program, *args,
#     227     stdin=stdin, stdout=stdout,
#     228     stderr=stderr, **kwds)
#     229 return Process(transport, protocol, loop)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py:1756, in BaseEventLoop.subprocess_exec(self, protocol_factory, program, stdin, stdout, stderr, universal_newlines, shell, bufsize, encoding, errors, text, *args, **kwargs)
#    1754     debug_log = f'execute program {program!r}'
#    1755     self._log_subprocess(debug_log, stdin, stdout, stderr)
# -> 1756 transport = await self._make_subprocess_transport(
#    1757     protocol, popen_args, False, stdin, stdout, stderr,
#    1758     bufsize, **kwargs)
#    1759 if self._debug and debug_log is not None:
#    1760     logger.info('%s: %r', debug_log, transport)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py:528, in BaseEventLoop._make_subprocess_transport(self, protocol, args, shell, stdin, stdout, stderr, bufsize, extra, **kwargs)
#     524 async def _make_subprocess_transport(self, protocol, args, shell,
#     525                                      stdin, stdout, stderr, bufsize,
#     526                                      extra=None, **kwargs):
#     527     """Create subprocess transport."""
# --> 528     raise NotImplementedError
#
# NotImplementedError:
